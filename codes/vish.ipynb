# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_feather(r"../data/train.feather")

# %%
train_data.head().T
# Out:
#                                                                    0  \
# Id                                                                 0
# GameRulesetName                                                  00Y
# agent1                        MCTS-ProgressiveHistory-0.1-MAST-false
# agent2                   MCTS-ProgressiveHistory-0.6-Random200-false
# Properties                                                         1
# ...                                                              ...
# LudRules           (game "00'Y'" (players 2) (equipment { (board ...
# num_wins_agent1                                                    4
# num_draws_agent1                                                   0
# num_losses_agent1                                                 11
# utility_agent1                                             -0.466667
#
#                                                                    1  \
# ...

# %%
train_data.columns
# Out:
# Index(['Id', 'GameRulesetName', 'agent1', 'agent2', 'Properties', 'Format',
#        'Time', 'Discrete', 'Realtime', 'Turns',
#        ...
#        'DoLudeme', 'Trigger', 'PlayoutsPerSecond', 'MovesPerSecond',
#        'EnglishRules', 'LudRules', 'num_wins_agent1', 'num_draws_agent1',
#        'num_losses_agent1', 'utility_agent1'],
#       dtype='object', length=814)

# %%
train_data[['GameRulesetName','agent1', 'agent2']].drop_duplicates()
# Out:
#        GameRulesetName                                        agent1  \
# 0                  00Y        MCTS-ProgressiveHistory-0.1-MAST-false
# 1                  00Y        MCTS-ProgressiveHistory-0.1-MAST-false
# 2                  00Y         MCTS-ProgressiveHistory-0.1-MAST-true
# 3                  00Y         MCTS-ProgressiveHistory-0.1-MAST-true
# 4                  00Y         MCTS-ProgressiveHistory-0.1-MAST-true
# ...                ...                                           ...
# 233229     Zuz_Mel_7x7        MCTS-UCB1Tuned-1.41421356237-NST-false
# 233230     Zuz_Mel_7x7  MCTS-UCB1Tuned-1.41421356237-Random200-false
# 233231     Zuz_Mel_7x7  MCTS-UCB1Tuned-1.41421356237-Random200-false
# 233232     Zuz_Mel_7x7  MCTS-UCB1Tuned-1.41421356237-Random200-false
# 233233     Zuz_Mel_7x7   MCTS-UCB1Tuned-1.41421356237-Random200-true
#
#                                                    agent2
# 0             MCTS-ProgressiveHistory-0.6-Random200-false
# ...
